# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
#importing data
student=pd.read_csv(r"C:\Users\Anuradha\Downloads\StudentsPerformance.csv")

# %%
#reading data
student.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
student.tail()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86

# %%
student.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
student.shape
# Out:
# (1000, 8)

# %%
#Descriptive sTATISTICS
student.describe()  #This give the description of numeric column only
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
student.describe(include="O") #THIS GIVES THE DESCRIPTION OG OBJECT COLUMN ONLY
# Out:
#         gender race/ethnicity parental level of education     lunch  \
# count     1000           1000                        1000      1000
# unique       2              5                           6         2
# top     female        group C                some college  standard
# freq       518            319                         226       645
#
#        test preparation course
# count                     1000
# unique                       2
# top                       none
# freq                       642

# %%
student.describe(include="all") #this gives the description for all the columns
# Out:
#         gender race/ethnicity parental level of education     lunch  \
# count     1000           1000                        1000      1000
# unique       2              5                           6         2
# top     female        group C                some college  standard
# freq       518            319                         226       645
# mean       NaN            NaN                         NaN       NaN
# std        NaN            NaN                         NaN       NaN
# min        NaN            NaN                         NaN       NaN
# 25%        NaN            NaN                         NaN       NaN
# 50%        NaN            NaN                         NaN       NaN
# 75%        NaN            NaN                         NaN       NaN
# max        NaN            NaN                         NaN       NaN
#
#        test preparation course  math score  reading score  writing score
# count                     1000  1000.00000    1000.000000    1000.000000
# ...

# %% [markdown]
# NUMERICAL COLUMNS: MEAN,MEDIAN STANDARD DEVIATION,PERCENTILE,MAXIMUM HAVE BEEN POPULATED.
# CATEGORICAL COLUMN: COUNT,UNIQUE,MODE HAVE BEEN POPULATED.

# %%
#FINDING MISSING VALUES
student.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %% [markdown]
# There are no missing values in our dataset

# %% [markdown]
# #### Graphical Representation

# %% [markdown]
# ##### Univariate Analysis

# %%
df["gender"].value_counts()
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %%
plt.figure(figsize=(8,7))
df["gender"].value_counts().plot(kind="bar",title="Gender of students",color=["pink","blue"])
# Out:
# <Axes: title={'center': 'Gender of students'}>

# %% [markdown]
# ###### Girls are more than boys in the school

# %%
df["race/ethnicity"].value_counts().plot(kind="bar",title="Race/Ethenicity of student",color=["red","orange","blue","pink","green"])
# Out:
# <Axes: title={'center': 'Race/Ethenicity of student'}>

# %% [markdown]
# ###### The maijority of students belongs to C AND D GROUP.

# %%
df["lunch"].value_counts().plot(kind="bar",title="Lunch of the student")
# Out:
# <Axes: title={'center': 'Lunch of the student'}>

# %% [markdown]
# ###### MORE THAN 60% OF STUDENT HAVE STANDARD LUNCH AT SCHOOL.

# %%
df["test preparation course"].value_counts().plot(kind="bar",title="Test preparation course",color=["green","black"])
# Out:
# <Axes: title={'center': 'Test preparation course'}>

# %% [markdown]
# ###### MORE THAN 60% STUDENT HAVE NOT TAKEN ANY PARTICIPATION IN TEST.

# %%
#fINDING OUT THE OUTLIERS FORM THE DATASET
student.boxplot()
# Out:
# <Axes: >

# %% [markdown]
# ###### Here we can see the outliers but we are not going to remove it because student math score,reading score or writing score can be low

# %%
#finding out the normalization of data
sns.distplot(df["math score"])
# Out:
# <Axes: xlabel='math score', ylabel='Density'>

# %%
mean=df["math score"].mean()
print("The mean of the math score column is",mean)
median=df["math score"].median()
print("The Median of the math score is",median)
mode=df["math score"].mode()
print("The mode of the math score is",mode)
# Out:
# The mean of the math score column is 66.089
# The Median of the math score is 66.0
# The mode of the math score is 0    65
# Name: math score, dtype: int64

# %% [markdown]
# ###### From above we can see that the math score column is Normally distributed.

# %%
sns.distplot(df["reading score"])
# Out:
# <Axes: xlabel='reading score', ylabel='Density'>

# %%
mean=df["reading score"].mean()
print("The mean of the reading score is",mean)
median=df["reading score"].median()
print("The median of the reading score is", median)
mode=df["reading score"].mode()
print("The mode of the reading score is",mode)
# Out:
# The mean of the reading score is 69.169
# The median of the reading score is 70.0
# The mode of the reading score is 0    72
# Name: reading score, dtype: int64

# %%
student["reading_score"]=student["reading score"].apply(lambda x:np.log(x))

# %%
student["reading_score"]
# Out:
# 0      4.276666
# 1      4.499810
# 2      4.553877
# 3      4.043051
# 4      4.356709
#          ...
# 995    4.595120
# 996    4.007333
# 997    4.262680
# 998    4.356709
# 999    4.454347
# Name: reading_score, Length: 1000, dtype: float64

# %%
sns.distplot(student["reading_score"])
# Out:
# <Axes: xlabel='reading_score', ylabel='Density'>

# %%
mean=df["reading score"].mean()
print("The mean of the reading score is",mean)
median=df["reading score"].median()
print("The median of the reading score is", median)
mode=df["reading score"].mode()
print("The mode of the reading score is",mode)
# Out:
# The mean of the reading score is 69.169
# The median of the reading score is 70.0
# The mode of the reading score is 0    72
# Name: reading score, dtype: int64

# %% [markdown]
# ###### Log transformation doesn't make any changes.

# %%
#We will apply yeo johnson transformation technique on it.
from scipy.stats import yeojohnson
student_transformed,_=yeojohnson(df["reading score"])
# pt=PowerTransformer(method="yeo-johnson")
# student_transform=pt.fit_transform(student)

# %%
sns.distplot(student_transformed)
# Out:
# <Axes: ylabel='Density'>

# %%
mean=df["reading score"].mean()
print("The mean of the reading score is",mean)
median=df["reading score"].median()
print("The median of the reading score is", median)
mode=df["reading score"].mode()
print("The mode of the reading score is",mode)
# Out:
# The mean of the reading score is 69.169
# The median of the reading score is 70.0
# The mode of the reading score is 0    72
# Name: reading score, dtype: int64

# %% [markdown]
# ###### This method  also not working on this column

# %%
#normalization
from feature_engine import transformation
student_transform=transformation.YeoJohnsonTransformer(variables="reading score")
stud_ft=student_transform.fit_transform(student)

# %% [markdown]
# ###### Now the data is normally distributed.

# %%
sns.distplot(df["writing score"])
# Out:
# <Axes: xlabel='writing score', ylabel='Density'>

# %% [markdown]
# ###### Now we will normalize this column

# %%
student["writing score"].mean()
student["writing score"].median()
# student["writing score"].mode()
# Out:
# 69.0

# %%
student["writing score"].median()
# Out:
# 69.0

# %%
student["writing score"].mode()
# Out:
# 0    74
# Name: writing score, dtype: int64

# %%
#Log transformtion

# %%
transformed_student=np.log(student["writing score"])

# %%
sns.distplot(transformed_student)
# Out:
# <Axes: xlabel='writing score', ylabel='Density'>

# %%
transformed_student.mean()
# Out:
# 4.19139213096249

# %%
transformed_student.median()
# Out:
# 4.23410650459726

# %%
transformed_student.mode()
# Out:
# 0    4.304065
# Name: writing score, dtype: float64

# %% [markdown]
# ###### Now the column is normally distributed.

# %% [markdown]
# ###### Now we will check the correlation between three scores.

# %%
corr=student.corr()
corr
# Out:
#                math score  reading score  writing score  reading_score
# math score       1.000000       0.817580       0.802642       0.807993
# reading score    0.817580       1.000000       0.954598       0.982862
# writing score    0.802642       0.954598       1.000000       0.940909
# reading_score    0.807993       0.982862       0.940909       1.000000

# %%
sns.heatmap(corr,annot=True,square=True)
# Out:
# <Axes: >

# %% [markdown]
# ###### From heatmap three scores are highly correlated .Reading score has a correlation coefficiant of 0.95 with writing score.
# math score has 0.82 with reading score.
# and 0.80 with writing score.

# %% [markdown]
# ###### Bivariate analysis

# %% [markdown]
# finding the realtion between math score and writing score of differant genders.

# %%
sns.relplot(x="math score",y="writing score",hue="gender",data=student)

# %% [markdown]
# female student having high writing score whereas male student having higher math score

# %%
#finding performance in all based on there parents and preparation
#course
student.groupby("parental level of education")[["math score","reading score","writing score"]].mean().T.plot(figsize=(12,8))
# Out:
# <Axes: >

# %% [markdown]
# ###### from this we can say that student whose parents are more educated are performing well than the student whose parents are less educated.

# %%
#finding the impact of the test preparation on students performance

# %%
student.groupby("test preparation course")[["math score","reading score","writing score"]].mean().T.plot(kind="barh",figsize=(10,10))
# Out:
# <Axes: >

# %%
We can see here student who have complted the test preparation have performed better.
